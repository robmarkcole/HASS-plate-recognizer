# %% [markdown]
# http://docs.platerecognizer.com/#license-plate-recognition

# %%
import requests
from IPython.display import Image

# %%
PLATE_READER_URL = 'https://api.platerecognizer.com/v1/plate-reader/'

# %%
api_token = "___"

headers = {
    'Authorization': f'Token {api_token}',
}

# %%
# Image("car.jpg")

# %%
Image("two_cars.jpg")

# %%
# %%time
with open("two_cars.jpg", 'rb') as image_bytes:
    response = requests.post(PLATE_READER_URL, files={"upload": image_bytes}, headers=headers)

response.json()
# Out:
# CPU times: user 26.7 ms, sys: 7.69 ms, total: 34.4 ms
# Wall time: 1.03 s
# {'processing_time': 168.995,
#  'results': [{'box': {'xmin': 159, 'ymin': 284, 'xmax': 258, 'ymax': 333},
#    'plate': 'kbw468a',
#    'region': {'code': 'by', 'score': 0.086},
#    'score': 0.899,
#    'candidates': [{'score': 0.899, 'plate': 'kbw468a'},
#     {'score': 0.777, 'plate': 'kbw46ba'},
#     {'score': 0.775, 'plate': 'k8w468a'},
#     {'score': 0.653, 'plate': 'k8w46ba'}],
#    'dscore': 0.793,
#    'vehicle': {'score': 0.813,
#     'type': 'Sedan',
#     'box': {'xmin': 0, 'ymin': 116, 'xmax': 406, 'ymax': 430}}},
#   {'box': {'xmin': 759, 'ymin': 387, 'xmax': 892, 'ymax': 424},
#    'plate': 'kbw468a',
#    'region': {'code': 'nz', 'score': 0.042},
#    'score': 0.883,
#    'candidates': [{'score': 0.883, 'plate': 'kbw468a'},
#     {'score': 0.788, 'plate': 'kbw4684'},
#     {'score': 0.762, 'plate': 'kbw46ba'},
#     {'score': 0.76, 'plate': 'k8w468a'},
#     {'score': 0.667, 'plate': 'kbw46b4'},
#     {'score': 0.665, 'plate': 'k8w4684'},
#     {'score': 0.639, 'plate': 'k8w46ba'},
#     {'score': 0.544, 'plate': 'k8w46b4'}],
#    'dscore': 0.677,
#    'vehicle': {'score': 0.694,
#     'type': 'SUV',
#     'box': {'xmin': 426, 'ymin': 66, 'xmax': 978, 'ymax': 480}}}],
#  'filename': '0655_4n6wb_two_cars.jpg',
#  'version': 1,
#  'camera_id': None,
#  'timestamp': '2021-02-12T06:55:36.616782Z'}
